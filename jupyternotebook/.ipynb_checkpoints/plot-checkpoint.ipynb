# %%
import matplotlib.pyplot as plt
import pandas

# %%
df = pandas.read_excel(r'C:\Users\Arvindh\Downloads\Volatility-cone (1).xlsx', sheet_name='temp')

# %%
df
# Out:
#   Days to Exp        10        20        30        45        60        90
# 0         Max  0.522567  0.464951  0.445793  0.434185  0.431878  0.389251
# 1        SD 2  0.556315  0.461960  0.446459  0.438807  0.423746  0.395014
# 2     SD    1  0.434225  0.374204  0.379642  0.369898  0.363058  0.351880
# 3        Mean  0.312134  0.286448  0.312826  0.300989  0.302370  0.308746
# 4      SD  -1  0.190044  0.198693  0.246009  0.232080  0.241681  0.265612
# 5       SD -2  0.067954  0.110937  0.179192  0.163171  0.180993  0.222478
# 6         Min  0.146395  0.186572  0.233001  0.216304  0.225250  0.265855
# 7          SD  0.122090  0.087756  0.066817  0.068909  0.060688  0.043134

# %%
df.set_index('Days to Exp', inplace=True)

# %%
df
# Out:
#                    10        20        30        45        60        90
# Days to Exp
# Max          0.522567  0.464951  0.445793  0.434185  0.431878  0.389251
# SD 2         0.556315  0.461960  0.446459  0.438807  0.423746  0.395014
# SD    1      0.434225  0.374204  0.379642  0.369898  0.363058  0.351880
# Mean         0.312134  0.286448  0.312826  0.300989  0.302370  0.308746
# SD  -1       0.190044  0.198693  0.246009  0.232080  0.241681  0.265612
# SD -2        0.067954  0.110937  0.179192  0.163171  0.180993  0.222478
# Min          0.146395  0.186572  0.233001  0.216304  0.225250  0.265855
# SD           0.122090  0.087756  0.066817  0.068909  0.060688  0.043134

# %%
df.T.plot()
# Out:
# <Axes: >
