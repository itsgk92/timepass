# %%
import nsepython

# %%
nsepython.nse_fno("BANKNIFTY")
# Out:
# {'info': {'symbol': 'BANKNIFTY',
#   'companyName': 'BANKNIFTY',
#   'identifier': 'none',
#   'activeSeries': [],
#   'debtSeries': [],
#   'isFNOSec': True,
#   'isCASec': False,
#   'isSLBSec': False,
#   'isDebtSec': False,
#   'isSuspended': False},
#  'filter': {'expiryDate': 'Invalid date', 'strikePrice': ''},
#  'underlyingValue': 48724.4,
#  'vfq': 901,
#  'fut_timestamp': '22-Jan-2025 15:30:01',
#  'opt_timestamp': '22-Jan-2025 15:30:02',
#  'stocks': [{'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '30-Jan-2025',
#     'optionType': 'Put',
#     'strikePrice': 48500,
#     'identifier': 'OPTIDXBANKNIFTY30-01-2025PE48500.00',
#     'openPrice': 485.8,
#     'highPrice': 764.95,
#     'lowPrice': 332.55,
#     'closePrice': 369.45,
#     'prevClose': 502.05,
#     'lastPrice': 363.1,
#     'change': -138.95,
#     'pChange': -27.67652624240613,
#     'numberOfContractsTraded': 1226110,
#     'totalTurnover': 104107.77},
#    'underlyingValue': 48724.4,
# ...
